# %% [markdown]
# <p style ="text-align:center">
#     <img src="http://epecora.com.br/DataFiles/BannerUFPR.png" width="700" alt="PPGOLD/PPGMNE Python:INTRO"  />
# </p>
#
# ## Prof. Eduardo Pécora, Ph.D.
#
# # Data Science
#
# ## Story Telling
#
# * Toda esta aula foi baseada nos exemplos de Kaflic (2019) agradeço a autora pelo maravilhoso livro.
# * *Tempo estimado **60** minutos*
# ## Objetivos
#
# Após completar essa aula você será capaz de :
# * Criar gráficos atraentes
# * Realizar storytelling com dados

# %% [markdown]
# ## Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Obtendo Dados

# %%
df = pd.read_csv("https://raw.githubusercontent.com/EduPekUfpr/PythonProject/refs/heads/main/Dados/DataTickets.csv")
print(df.shape)
df.head(12)
# Out:
# (12, 3)
#           Mes  Recebidos  Processados
# 0     Janeiro      160.0        160.0
# 1   Fevereiro      184.0        184.0
# 2       Março      241.0        237.0
# 3       Abril      149.0        148.0
# 4        Maio      180.0        181.0
# 5       Junho      161.0        150.0
# 6       Julho      132.0        123.0
# 7      Agosto      202.0        156.0
# 8    Setembro      160.0        126.0
# 9     Outubro      139.0        104.0
# 10   Novembro      149.0        124.0
# 11   Dezembro      177.0        140.0

# %% [markdown]
# ### Transformar do dados em um formato mais adequado apara gerar os gráficos

# %%
df = df.melt(id_vars="Mes",
        var_name="Status",
        value_name="Value")

df.head(24)
# Out:
#           Mes       Status  Value
# 0     Janeiro    Recebidos  160.0
# 1   Fevereiro    Recebidos  184.0
# 2       Março    Recebidos  241.0
# 3       Abril    Recebidos  149.0
# 4        Maio    Recebidos  180.0
# 5       Junho    Recebidos  161.0
# 6       Julho    Recebidos  132.0
# 7      Agosto    Recebidos  202.0
# 8    Setembro    Recebidos  160.0
# 9     Outubro    Recebidos  139.0
# 10   Novembro    Recebidos  149.0
# 11   Dezembro    Recebidos  177.0
# 12    Janeiro  Processados  160.0
# 13  Fevereiro  Processados  184.0
# 14      Março  Processados  237.0
# 15      Abril  Processados  148.0
# 16       Maio  Processados  181.0
# 17      Junho  Processados  150.0
# 18      Julho  Processados  123.0
# 19     Agosto  Processados  156.0
# 20   Setembro  Processados  126.0
# 21    Outubro  Processados  104.0
# 22   Novembro  Processados  124.0
# 23   Dezembro  Processados  140.0

# %% [markdown]
# ### Contexto

# %% [markdown]
# A área de Henrique um gerente de TI, está com um problema pois exitem muito mais chamados (tickets) do que a capacidade de atendimento. Isso se deve ao fato de há alguns meses dois de seus melhores funcionários terem se formado Mestres no PPGOLD e portanto conseguiram um emprego muito melhor.
#
# Amanhã Herique tem um reunião com o Diretor e tem 5 minutos para explicar o caso e então pleitear a contratação de mais dois funcionários.
#
# -----
#
# Para cada um dos gráficos abaixo eu quero que você pense:
#
# 1) Qual o elemento do gráfico que você viu primeiro?
# 2) E o segundo ?
# 3) Quanto tempo você demoraria para explicar este gráfico para o diretor?
# 4) O que pode ser melhroado no gráfico?

# %%
# Definir um tema 'limpo'
sns.set_theme()

# Aumentar a área do Gráfico
plt.figure(figsize=(16,12),facecolor='skyblue')

# Barplot
ax = sns.barplot(x="Mes", y="Value", hue = "Status", data=df)

# adiciona valores no alto das barras
for container in ax.containers:
    ax.bar_label(container, size = 18)

# Define o intervalo de valores do eixo Y
ax.set(ylim=(90, 250))

# Aplica o formato de três valores decimais no eixo
from matplotlib.ticker import StrMethodFormatter # Biblioteca para formatar números nos eixos dos gráficos
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}'))

# Nomes e fontes dos eixos
plt.xlabel("Mês", size = 15) # Label e fontSize to eixo x
plt.ylabel("Quantidade de Tickets", size = 20) # Label e fontSize to eixo y
plt.title("Tendência dos Tickets", fontsize=20) # Título e fontSize do Gráfico
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x

# Nomes, fontes e cores da legenda
frame = plt.legend(title = "Status", fontsize=20, title_fontsize=25, bbox_to_anchor=(1.05, 1), borderaxespad=0).get_frame() # Box da legenda
frame.set_facecolor('r') # Cor do box da legenda

# Finaliza o Gráfico
plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme()
plt.figure(figsize=(16,12),facecolor='skyblue') # Aumentar a área do Gráfico

ax = sns.barplot(x="Mes", y="Value", hue = "Status", data=df) # Barplot
for container in ax.containers: #adiciona valores no alto das barras
    ax.bar_label(container, size = 18)
ax.set(ylim=(90, 250)) # intervalo de valores do eixo Y
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # three decimal places
plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x

# ********
# Retira a caixa vermelha da legenda
plt.legend(title = "Status", fontsize=20, title_fontsize=25, bbox_to_anchor=(1.05, 1), borderaxespad=0) # Box da legenda
# ********

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
# ********
# Define um fundo branco
sns.set_theme(style="whitegrid") # fundo branco
# ********

plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico
ax = sns.barplot(x="Mes", y="Value", hue = "Status", data=df) # Barplot
for container in ax.containers: #adiciona valores no alto das barras
    ax.bar_label(container, size = 18)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # three decimal places
ax.set(ylim=(90, 250)) # intervalo de valores do eixo Y
plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(title = "Status", fontsize=20, title_fontsize=25, bbox_to_anchor=(1.05, 1), borderaxespad=0) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico
ax = sns.barplot(x="Mes", y="Value", hue = "Status", data=df) # Barplot
for container in ax.containers: #adiciona valores no alto das barras
    ax.bar_label(container, size = 18)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # three decimal places

# ********
# Corrije o intervalo do o eixo Y
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
# ********

plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(title = "Status", fontsize=20, title_fontsize=25, bbox_to_anchor=(1.05, 1), borderaxespad=0) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico

ax = sns.barplot(x="Mes", y="Value", hue = "Status", data=df) # Barplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
for container in ax.containers: #adiciona valores no alto das barras
    ax.bar_label(container, size = 18)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # three decimal places
plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x

# ********
# Muda a legenda de lugar
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda
# ********

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %% [markdown]
# ### O Gráfico de barras é o mais apropriado para este contexto?

# %% [markdown]
# Nossos os olhos leem gráfico de barras facilmente. Eles comparam os pontos extremos as barras, de modo que é fácil ver rapidamente qual é a categoria maior, qual é a menor e a diferença incremental entre as categorias. (Kaflic,2019)
#
# O gráfico de barras são comuns e fácil de ler, em vez de usar o poder do cérebro para tentar ler o gráfico o público utiliza para decidir qual informação extraír da apresentação.(Kaflic,2019)

# %% [markdown]
# ### O Gráfico de linhas
#
# Os gráficos de linhas são mais usados para registrar dados contínuos. Como, os dados estão fisicamente conectados por meio da linha, isso indica uma conexão entre eles, que pode não fazer sentido para dados categóricos. Frequentemente nossos dados contínuos estão em alguma unidade de tempo dias meses trimestre ou anos. (kaflic,2019)
#
# Os gráficos de linha também podem ser usados para mostrar uma evolução temporal de uma variável.

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico

# ********
# Gráfico de linhas
ax = sns.lineplot(x="Mes", y="Value", hue = "Status", data=df, style='Status', markers=True, dashes=False, linewidth = 3, markersize = 15) # lineplot
# ********

plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.3f}')) # three decimal places
for x, y in zip(df['Mes'], df['Value']):
    ax.text(x = x,
            y = y,
            s = '{:.0f}'.format(y),
            fontsize = 15
           )
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y

plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico

ax = sns.lineplot(x="Mes", y="Value", hue = "Status", data=df, style='Status', markers=True, dashes=False, linewidth = 3, markersize = 15) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y

# ********
# Retira as casas decimais desnecessáriasdo eixo Y
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # No decimal places
# ********

for x, y in zip(df['Mes'], df['Value']):
    ax.text(x = x,
            y = y,
            s = '{:.0f}'.format(y),
            fontsize = 15
           )

plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico

ax = sns.lineplot(x="Mes", y="Value", hue = "Status", data=df, style='Status', markers=True, dashes=False, linewidth = 3, markersize = 15) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y

# ********
# Retira os valores de cada ponto

#for x, y in zip(df['Mes'], df['Value']):
#    ax.text(x = x,
#            y = y,
#            s = '{:.0f}'.format(y),
#            fontsize = 15
#           )
# ********

plt.xlabel("Mês", size = 15)
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,12)) # Aumentar a área do Gráfico

ax = sns.lineplot(x="Mes", y="Value", hue = "Status", data=df, style='Status', markers=True, dashes=False, linewidth = 3, markersize = 15) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y

# ********
# Retira título desnecessátio no eixo x
plt.xlabel("")
# ********

plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.2), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco

# ********
# Corrije o formato do gráfico, dando uma largura maior
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico
# ********

ax = sns.lineplot(x="Mes", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 3) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)

# ********
# Retira das linhas verticais
ax.xaxis.grid(False) # Hide the VERTICAL gridlines
# ********

plt.xlabel("")
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20, rotation=45) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

# ********
# Corrije a inclinação dos ®otulos do eixo x e troca os nomes por algo mais sintético
df["MesShort"] = df["Mes"].str[0:3]
ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 3) # lineplot
# ********

ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend(fontsize=20, bbox_to_anchor=(0.5, -0.25), loc = "lower center", ncol = df.shape[1], borderaxespad=0, frameon=False) # Box da legenda

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 3) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x

# ********
# Retira a legenda padrão e coloca um seguindo as linhas
# facilitando a leitura, pois nosso olhos não precisam mudar de posição
plt.legend([],[], frameon=False)

ax.text(x = 11.1,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 20,
           )

ax.text(x = 11.1,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 20,
           )
# ********

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 3) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x

plt.legend([],[], frameon=False)

# ********
# Adequa as cores dos textos para a mesma dos gráfico
palete_name = "tab10"
palette = sns.color_palette(palete_name, 10)
sns.set_palette(palete_name)

ax.text(x = 11.1,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 20,
            color = palette[0]
           )

ax.text(x = 11.1,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 20,
            color = palette[1]
           )
# ********

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

palete_name = "tab10"

palette = sns.color_palette(palete_name, 10)
sns.set_palette(palete_name)

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("Quantidade de Tickets", size = 20)
plt.title("Tendência dos Tickets", fontsize=20)
plt.yticks(size = 15)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

# ********
# Enfatizo o que quero chamar a atenção
ax.text(x = 11.1,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.1,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )
# ********

# ********
# Tiro a enfaze de onde não quero chamar a atenção
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ********



plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

palete_name = "tab10"

palette = sns.color_palette(palete_name, 10)
sns.set_palette(palete_name)

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("")

plt.yticks(size = 20)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

ax.text(x = 11.1,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.1,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# ********
# Colocar título do gráfico e dos eixos para algo mais adequado em uma posição mais discreta
# Sigo o alinhamento dos limites do gráfico
ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

ax.text(x = -0.27,
            y = -32,
            s ='2020',
            fontsize = 20,
            color = "k",
           )

ax.text(x = -1.5,
            y = 155,
            s ='Número de tickets',
            fontsize = 20,
            rotation="vertical",
            color = "k",
           )
# ********

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

# ********
# Enfatizo o dados mais importante
colors = ["#7F7F7F", "#2A299F"]
palette = sns.color_palette(colors)
sns.set_palette(palette)
# ********

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.2)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.xlabel("")
plt.ylabel("")
#plt.title("Evolução dos Tickets", fontsize=25, loc = "left")
ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)


plt.yticks(size = 20)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

ax.text(x = 11.1,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.1,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

ax.text(x = -0.27,
            y = -32,
            s ='2020',
            fontsize = 20,
            color = "k",
           )

ax.text(x = -1.5,
            y = 155,
            s ='Número de tickets',
            fontsize = 20,
            rotation="vertical",
            color = "k",
           )

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

colors = ["#7F7F7F", "#2A299F"]

palette = sns.color_palette(colors)
sns.set_palette(palette)

# ********
# Chamo a atenção para os valores finais
printMonths = ['Ago', 'Set', 'Out', 'Nov', 'Dez']
dictMonths = {'Jan':1,'Fev':2,'Mar':3,'Abr':4,'Mai':5,'Jun':6,'Jul':7,'Ago':8,'Set':9,'Out':10,'Nov':11,'Dez':12}
marker_on = [7,8,9,10,11]
# ********

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5, markers= ["s","s"], ms=12, markevery=marker_on) # lineplot
ax.set(ylim=(0, 250)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.002)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # NO decimal places
for x, y, z in zip(df['MesShort'], df['Value'], df['Status']):
    if x in printMonths:
        if z == "Recebidos":
            ax.text(x = dictMonths[x] - 1.2,
                y = y + 10,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )
        else:
            ax.text(x = dictMonths[x] - 1.2,
                y = y - 15,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )

plt.xlabel("")
plt.ylabel("")
ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

plt.yticks(size = 20)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

ax.text(x = 11.3,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.3,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

ax.text(x = -0.27,
            y = -32,
            s ='2020',
            fontsize = 20,
            color = "k",
           )

ax.text(x = -1.5,
            y = 155,
            s ='Número de tickets',
            fontsize = 20,
            rotation="vertical",
            color = "k",
           )

plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

colors = ["#7F7F7F", "#2A299F"]

palette = sns.color_palette(colors)
sns.set_palette(palette)

printMonths = ['Ago', 'Set', 'Out', 'Nov', 'Dez']
dictMonths = {'Jan':1,'Fev':2,'Mar':3,'Abr':4,'Mai':5,'Jun':6,'Jul':7,'Ago':8,'Set':9,'Out':10,'Nov':11,'Dez':12}
marker_on = [7,8,9,10,11]

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5, markers= ["s","s"], ms=12, markevery=marker_on) # lineplot
ax.set(ylim=(0, 300)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.002)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # NO decimal places
for x, y, z in zip(df['MesShort'], df['Value'], df['Status']):
    if x in printMonths:
        if z == "Recebidos":
            ax.text(x = dictMonths[x] - 1.2,
                y = y + 10,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )
        else:
            ax.text(x = dictMonths[x] - 1.2,
                y = y - 15,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )

plt.xlabel("")
plt.ylabel("")
ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

plt.yticks(size = 20)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

ax.text(x = 11.3,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.3,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_ticks_position('left')

ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)


ax.text(x = -1.5,
            y = 185,
            s ='Número de tickets',
            fontsize = 20,
            rotation="vertical",
            color = "k",
           )
# ********
# Adiciono um elemento textual auto-explicativo
ax.text(x = 4,
        y = 235,
        s = ' 2 Funcionários saíram em maio. Praticamente acompanhamos \n o volume recebido nos dois meses seguintes, mas não em agosto; \n desde então, não conseguimos mais acompanhar',
        fontsize = 17,
        color = "k",
        )
# ********

ax.text(x = -0.26,
            y = -35,
            s ='2020',
            fontsize = 20,
            color = "k",
           )

plt.vlines(x=["Mai"], ymin=0, ymax=250,linestyles = "dashed", color = 'grey')


plt.show()

# %%
sns.set_theme(style="whitegrid") # fundo branco
plt.figure(figsize=(16,8)) # Aumentar a área do Gráfico

colors = ["#7F7F7F", "#2A299F"]

palette = sns.color_palette(colors)
sns.set_palette(palette)

printMonths = ['Ago', 'Set', 'Out', 'Nov', 'Dez']
dictMonths = {'Jan':1,'Fev':2,'Mar':3,'Abr':4,'Mai':5,'Jun':6,'Jul':7,'Ago':8,'Set':9,'Out':10,'Nov':11,'Dez':12}
marker_on = [7,8,9,10,11]

ax = sns.lineplot(x="MesShort", y="Value", hue = "Status", data=df, style='Status', dashes=False, linewidth = 5, markers= ["s","s"], ms=12, markevery=marker_on) # lineplot
ax.set(ylim=(0, 300)) # intervalo de valores do eixo Y
ax.grid(which='major', color='darkgrey', linewidth=0.002)
ax.xaxis.grid(False) # Hide the VERTICAL gridlines

plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}')) # NO decimal places
for x, y, z in zip(df['MesShort'], df['Value'], df['Status']):
    if x in printMonths:
        if z == "Recebidos":
            ax.text(x = dictMonths[x] - 1.2,
                y = y + 10,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )
        else:
            ax.text(x = dictMonths[x] - 1.2,
                y = y - 15,
                s = '{:.0f}'.format(y),
                fontsize = 15,
                weight='bold'
           )

plt.xlabel("")
plt.ylabel("")
ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)

plt.yticks(size = 20)  # FontSize do eixo y
plt.xticks(size = 20) # FontSize do eixo x
plt.legend([],[], frameon=False)

ax.text(x = 11.3,
            y = 177,
            s = 'Recebidos'.format(y),
            fontsize = 25,
            color = palette[0],
            weight='bold'
           )

ax.text(x = 11.3,
            y = 140,
            s = 'Processados'.format(y),
            fontsize = 25,
            color = palette[1],
            weight='bold'
           )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_ticks_position('left')

ax.set_title("Volume de tickets ao longo do tempo", fontsize=25, y=1.1, x=0.18)


ax.text(x = -1.5,
            y = 185,
            s ='Número de tickets',
            fontsize = 20,
            rotation="vertical",
            color = "k",
           )
# ********
# Adiciono um elemento textual auto-explicativo
ax.text(x = 4,
        y = 235,
        s = ' 2 Funcionários saíram em maio',
        fontsize = 17,
        color = "k",
        )
# ********

ax.text(x = -0.26,
            y = -35,
            s ='2020',
            fontsize = 20,
            color = "k",
           )

plt.vlines(x=["Mai"], ymin=0, ymax=250,linestyles = "dashed", color = 'grey')


plt.show()

# %% [markdown]
# ### Quais os dois elementos que mais te chamaram a atenção no gráfico acima?

# %% [markdown]
# 1) ...
# 2) ...

# %% [markdown]
# ## Compare o gráfico inicial com este

# %% [markdown]
# ### Quanto tempo você demoraria para explicar este gráfico para o diretor?

# %% [markdown]
# ## Fique Conectado
#
# - [![YouTube](https://img.icons8.com/?size=40&id=19318&format=png&color=000000)](https://www.youtube.com/@LigaDataScience/videos)
#   Explore nossos vídeos educacionais e webinars sobre ciência de dados, machine learning e inteligência artificial. Inscreva-se para não perder nenhuma atualização!
#
# - [![LinkedIn](https://img.icons8.com/?size=40&id=13930&format=png&color=000000)](https://www.linkedin.com/company/liga-data-science-ufpr/)
#   Siga-nos no LinkedIn para as últimas novidades, oportunidades de carreira e networking profissional no campo da ciência de dados.
#
# - [![Instagram](https://img.icons8.com/?size=40&id=32323&format=png&color=000000)](https://www.instagram.com/ligadatascience/)
#   Confira nosso Instagram para conteúdos dos bastidores, destaques de eventos e o dia a dia da Liga Data Science. Faça parte da nossa jornada!
#
#
# ## Bibliografia Básica
#
# * Kaflic, C.N. (2019) "Storytelling com dados" Editora Alta Books
#
# ## Bibliografia de apoio
#
# * https://www.statology.org/seaborn-legend-size/
# * https://www.statology.org/matplotlib-legend-position/
#
# * https://seaborn.pydata.org/generated/seaborn.barplot.html
# * https://seaborn.pydata.org/generated/seaborn.axes_style.html
# * https://seaborn.pydata.org/tutorial/aesthetics.html
# * https://seaborn.pydata.org/generated/seaborn.lineplot.html
#
# * https://www.kaggle.com/asimislam/python-colors-color-cmap-palette
# * https://matplotlib.org/stable/gallery/color/named_colors.html
# * https://seaborn.pydata.org/tutorial/color_palettes.html
# * https://towardsdatascience.com/how-to-use-your-own-color-palettes-with-seaborn-a45bf5175146
#
# * https://newbedev.com/matplotlib-specify-format-of-floats-for-tick-labels
#
# * https://matplotlib.org/stable/gallery/text_labels_and_annotations/titles_demo.html
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.vlines.html
# * https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.yticks.html

# %% [markdown]
# ## Autores
#
# <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pecora</a>
#
# <a href="https://www.linkedin.com/in/hesauhugocavalcanti/" target="_blank">Hesau Hugo</a>
#
# ## Log de modificações
#
# | Data | Versão | Modificado por | Descrição |
# | ----------------- | ------- | ---------- | ---------------------------------- |
# | 01-12-2021       | 1.0     | Eduardo Pecora    | Criação               |
# | 17-04-2023       | 1.1     | Hesau Hugo        | Refatorado        |
#
# <hr>
