# %% [markdown]
# <p style ="text-align:center">
#     <img src="http://epecora.com.br/DataFiles/BannerUFPR.png" width="700" alt="PPGOLD/PPGMNE Python:INTRO"  />
# </p>
#
#
# # SAOP09 - Data Science For Business
# ## Prof. Eduardo Pécora
#
# # Manipulação de DataFrame e Análise Exploratória de DadosTempo estimado: **60** minutos
#
# ## Objetivos
#
# Após completar esta aula, você será capaz de:
#
# * Executar uma análise descritiva do DF
# * Fazer os primeiros gráficos usando Matplotlib e Seaborn
# * Interpretar os dados

# %%
#Neste exemplo iremos usar as bibliotecas pandas e numpy, 
#e também as gráficas (matplotlib e seaborn) e também uma estatística (scipy.stats)

# import libraries
import pandas as pd  # Biblioteca para os DataFrames 
import numpy as np   # Biblioteca Numérica
import matplotlib.pyplot as plt
import seaborn as sns

# comando para imprimir os gráficos
# %matplotlib inline 

# Gráficos maiores
sns.set(rc={'figure.figsize':(10,7)})

import scipy.stats as stats

# Ler o arquivo, e atribua-o à variável "df".
# Fonte: https://www.gapminder.org/data/
my_file = "https://raw.githubusercontent.com/EduPekUfpr/PythonProject/refs/heads/main/Dados/data_countries_clean.csv"
df = pd.read_csv(my_file)

# %% [markdown]
# ## Aquela olhada no Data Frame

# %%
# No GOOGLE COLAB você terá que instalar a biblioteca
# Execute o comando abaixo
# ! pip install ydata_profiling

from ydata_profiling import ProfileReport

# profile = ProfileReport(df, minimal = True, title="Countries Report")
profile = ProfileReport(df, title="Countries Report")
profile.to_file(output_file="output_min.html")
print("Arquivo salvo como output_min.html")
# display(profile.to_notebook_iframe())
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 1941.28it/s]0:00, 12.01it/s, Describe variable: suicide_per_100000_people]
# Summarize dataset: 100%|██████████| 143/143 [00:42<00:00,  3.40it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:08<00:00,  8.58s/it]
# Render HTML: 100%|██████████| 1/1 [00:07<00:00,  7.37s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 20.26it/s]
# Arquivo salvo como output_min.html

# %%
df.head()
# Out:
#        country  year  basic_sanitation_access_percent  \
# 0  Afghanistan  1999                             23.5
# 1  Afghanistan  2000                             23.5
# 2  Afghanistan  2001                             24.6
# 3  Afghanistan  2002                             25.8
# 4  Afghanistan  2003                             26.9
#
#    child_mortality_0_5_year_olds_dying_per_1000_born  \
# 0                                              129.0
# 1                                              125.0
# 2                                              121.0
# 3                                              117.0
# 4                                              113.0
#
#    children_per_woman_total_fertility  co2_emissions_tonnes_per_person  \
# 0                                7.49                           0.0370
# 1                                7.39                           0.0376
# 2                                7.27                           0.0471
# 3                                7.14                           0.0509
# 4                                6.99                           0.0368
#
#    employment_rate_percent    hdi  \
# 0                     45.9  0.345
# 1                     45.9  0.347
# 2                     47.7  0.378
# 3                     47.9  0.387
# 4                     47.5  0.400
#
#    income_per_person_gdppercapita_ppp_inflation_adjusted  life_expectancy  \
# 0                                                578                 54.7
# 1                                                563                 54.8
# 2                                               1190                 55.5
# 3                                               1240                 56.5
# 4                                               1200                 57.1
#
#    population_total  suicide_per_100000_people
# 0          20800000                        NaN
# 1          21600000                        NaN
# 2          22600000                        NaN
# 3          23700000                        NaN
# 4          24700000                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3613 entries, 0 to 3612
# Data columns (total 12 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   country                                                3613 non-null   object
#  1   year                                                   3613 non-null   int64
#  2   basic_sanitation_access_percent                        3115 non-null   float64
#  3   child_mortality_0_5_year_olds_dying_per_1000_born      3613 non-null   float64
#  4   children_per_woman_total_fertility                     3613 non-null   float64
#  5   co2_emissions_tonnes_per_person                        3613 non-null   float64
#  6   employment_rate_percent                                3613 non-null   float64
#  7   hdi                                                    3613 non-null   float64
#  8   income_per_person_gdppercapita_ppp_inflation_adjusted  3613 non-null   int64
#  9   life_expectancy                                        3613 non-null   float64
#  10  population_total                                       3613 non-null   int64
#  11  suicide_per_100000_people                              1304 non-null   float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 338.8+ KB

# %% [markdown]
# ## Vamos trocar os nomes das colunas por algo mais curto?
#
# | #      | Column                                                | ShortName       | Count | Dtype   |
# |--------|-------------------------------------------------------|-----------------|-------|---------|
# | 0      | country                                               | country         | 806   | object  |
# | 1      | year                                                  | year            | 806   | int64   |
# | 2      | basic_sanitation_access_percent                       | sanitation      | 806   | float64 |
# | 3      | child_mortality_0_5_year_olds_dying_per_1000_born     | child_mortality | 806   | float64 |
# | 4      | children_per_woman_total_fertility                    | total_fertility | 806   | float64 |
# | 5      | co2_emissions_tonnes_per_person                       | co2_emissions   | 806   | float64 |
# | 6      | employment_rate_percent                               | employment_rate | 806   | float64 |
# | 7      | hdi                                                   | hdi             | 806   | float64 |
# | 8      | income_per_person_gdppercapita_ppp_inflation_adjusted | gdp             | 806   | int64   |
# | 9      | life_expectancy                                       | life_expectancy | 806   | float64 |
# | 10     | population_total                                      | population      | 806   | int64   |
# | 11     | suicide_per_100000_people                             | suicide         | 806   | float64 |

# %%
df.columns = ['country', 'year', 'sanitation', 
              'child_mortality', 'total_fertility', 
              'co2_emissions', 'employment_rate', 
              'hdi', 'gdp', 'life_expectancy', 
              'population', 'suicide']

# %% [markdown]
# ## Estatísticas descritivas

# %%
df.describe()
# Out:
#               year   sanitation  child_mortality  total_fertility  \
# count  3613.000000  3115.000000      3613.000000      3613.000000
# mean   2005.762801    70.647913        37.844528         2.847794
# std       6.781467    30.773176        41.620144         1.521447
# min    1990.000000     3.400000         1.850000         0.950000
# 25%    2001.000000    44.050000         7.940000         1.660000
# 50%    2006.000000    85.600000        19.500000         2.290000
# 75%    2011.000000    97.600000        55.400000         3.780000
# max    2016.000000   100.000000       234.000000         7.680000
#
#        co2_emissions  employment_rate          hdi            gdp  \
# count    3613.000000      3613.000000  3613.000000    3613.000000
# mean        5.228571        57.090922     0.681361   18668.314143
# std         6.591079        11.023802     0.158159   19098.432749
# min         0.015900        28.900000     0.253000     563.000000
# 25%         0.752000        49.900000     0.565000    4160.000000
# 50%         2.990000        57.100000     0.705000   11500.000000
# 75%         7.720000        63.200000     0.806000   29000.000000
# max        67.100000        87.800000     0.953000  115000.000000
#
#        life_expectancy    population      suicide
# count      3613.000000  3.613000e+03  1304.000000
# mean         70.632438  3.669136e+07    11.845344
# std           8.461934  1.323415e+08     7.573063
# min          32.500000  9.800000e+04     0.045400
# 25%          65.500000  3.110000e+06     6.555000
# 50%          72.600000  8.680000e+06    10.900000
# 75%          77.000000  2.650000e+07    14.800000
# max          84.700000  1.420000e+09    44.300000

# %% [markdown]
# ### Como está distribuído o desemprego ?

# %%
sns.boxplot(x = "country", y = "employment_rate", data = df)
# Out:
# <Axes: xlabel='country', ylabel='employment_rate'>

# %%
sns.lineplot(x = "year", y = "employment_rate", hue = "country", data = df)
# Out:
# <Axes: xlabel='year', ylabel='employment_rate'>

# %% [markdown]
# ## Conclusão
#
# Existem muitos dados para podermos analisar de uma única vez, então vamos tratar o DF e fazer uma análise mais focada.

# %% [markdown]
# ## Como estão distribuídos os dados por países?

# %%
# Cria um novo DataFrame com a quantidade de dados por país

df_country = df['country'].value_counts().to_frame()
df_country
# Out:
#               count
# country
# Australia        27
# Armenia          27
# Austria          27
# Belgium          27
# Canada           27
# ...             ...
# Lebanon          13
# Eritrea          12
# Brunei            9
# Turkmenistan      8
# South Sudan       7
#
# [178 rows x 1 columns]

# %%
df_country.shape
# Out:
# (178, 1)

# %% [markdown]
# ## Conclusão
#
# Temos alguns países com poucos dados.

# %% [markdown]
# ## Como estão distribuídos os dados por anos?

# %%
# Cria um novo DataFrame com a quantidade de dados por ano

df_year = df['year'].value_counts().to_frame()
df_year.reset_index(inplace = True)
df_year.columns = ['year', 'total']
df_year.head()
# Out:
#    year  total
# 0  2012    178
# 1  2011    178
# 2  2010    178
# 3  2013    178
# 4  2014    178

# %% [markdown]
# ## Ordenar pelo ano

# %%
df_year.sort_values(by=['year'], inplace = True)
df_year.reset_index(inplace = True)
df_year.head()
# Out:
#    index  year  total
# 0     22  1990     54
# 1     20  1991     57
# 2     18  1992     60
# 3     19  1993     59
# 4     21  1994     57

# %% [markdown]
# ### Visualização Gráfica

# %%
sns.barplot(y = "year", x="total", data=df_year,  color='b',orient = "h")
# Out:
# <Axes: xlabel='total', ylabel='year'>

# %%
sns.barplot(x = "year", y="total", data=df_year,  color='b')
plt.title('Evolution of Data per year')
plt.xlabel('Year')
plt.ylabel('#Data')
# Out:
# Text(0, 0.5, '#Data')

# %%
sns.set(style='whitegrid', rc={"grid.linewidth": 0.1})

g = sns.lineplot(x = "year", y="total", data=df_year,  color='b',  linewidth = 5 )
g.axes.set_title('Evolution of Data per year',fontsize=30)
g.set_xlabel("Year",fontsize=20)
g.set_ylabel("#Data",fontsize=20)
g.tick_params(labelsize=17)

# %% [markdown]
# ## Conclusão
#
# Existem alguns anos com menos dados, ou seja, a coleta da dados foi ampliada em algum momento.

# %% [markdown]
# ## Seleção de um subconjunto de linhas do DataFrame
#
# Temos muitos países com poucos dados, vamos buscar mais dados ou faremos uma linha de corte?

# %%
pontoDeCorte = 20

#df_country = df['country'].value_counts().to_frame().reset_index()

# Contar o número de anos distintos para cada país
conta_anos = df.groupby('country')['year'].nunique()
lista_paises = conta_anos[conta_anos >= 20].index.tolist()
df_country = df[df['country'].isin(lista_paises)]

print(f"Lista de países com no mínimo {pontoDeCorte:d} anos de dados")
print(type(lista_paises))
print(lista_paises)
# Out:
# Lista de países com no mínimo 20 anos de dados
# <class 'list'>
# ['Albania', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Bulgaria', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba', 'Czech Republic', 'Denmark', 'El Salvador', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hong Kong, China', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy', 'Japan', 'Kazakhstan', 'Kuwait', 'Kyrgyz Republic', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Mauritius', 'Mexico', 'Moldova', 'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'Serbia', 'Singapore', 'Slovak Republic', 'Slovenia', 'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Tajikistan', 'Trinidad and Tobago', 'Ukraine', 'United Kingdom', 'United States']

# %% [markdown]
# Ainda são muitos, então vamos
#
# # Selecionar somente alguns países para analisar melhor

# %%
# Países
c = ['Norway', 'Sweden', 'Denmark', 'Luxembourg' ]
# Novo DataFrame com 4 países
df2 = df[df["country"].isin(c)]

# %% [markdown]
# ## Boxplots

# %%
g = sns.boxplot(x = "country", y = "employment_rate", data = df2)
g.axes.set_title('Employment Rate Box Plot',fontsize=30)
g.set_xlabel("Country",fontsize=20)
g.set_ylabel("Employment Rate",fontsize=20)
g.tick_params(labelsize=17)

# %%
c =  ['Germany','Switzerland','Iceland','Bulgaria']
df3 = df[df["country"].isin(c)]

g = sns.violinplot(x = "country", y = "suicide", data = df3)
g.axes.set_title('Suicides per 100K people',fontsize=30)
g.set_xlabel("Country",fontsize=20)
g.set_ylabel("Suicides",fontsize=20)
g.tick_params(labelsize=17)

# %%
g=sns.boxplot(x = "country", y = "suicide", data = df3)
g.axes.set_title('Suicides per 100K people',fontsize=30)
g.set_xlabel("Country",fontsize=20)
g.set_ylabel("Employment Rate",fontsize=20)
g.tick_params(labelsize=17)

# %% [markdown]
# ## Scatter Plot
#
# Todos os países

# %%
y = df["hdi"]
x = df["child_mortality"]

plt.scatter(x,y)

# %%
sns.scatterplot(data=df, y="hdi", x="child_mortality")
# Out:
# <Axes: xlabel='child_mortality', ylabel='hdi'>

# %% [markdown]
# ## Seleção de países

# %%
sns.scatterplot(data=df2, y="hdi", x="child_mortality", hue = "country")
# Out:
# <Axes: xlabel='child_mortality', ylabel='hdi'>

# %%
sns.set(style='whitegrid', rc={"grid.linewidth": 0.3})

g = sns.scatterplot(data=df2, y="hdi", x="child_mortality")
g.set_xlabel("Child (< 5 Years) Mortality per 1000 born",fontsize=20)
g.set_ylabel("HDI",fontsize=20)
g.tick_params(labelsize=17)

# %%
g= sns.scatterplot(data=df2, y="hdi", x="child_mortality", hue = "country")
g.set_xlabel("Child (< 5 Years) Mortality per 1000 born",fontsize=20)
g.set_ylabel("HDI",fontsize=20)
g.tick_params(labelsize=17)
plt.legend(loc="upper right", frameon=False, fontsize=15)

# %% [markdown]
# ## Grid Plot

# %%
#Selecionando algumas colunas e países

df4 = df2[["country","year", "sanitation", "child_mortality", "co2_emissions", "employment_rate", "life_expectancy"]]
c = ['Norway', 'Sweden', 'Denmark', 'Switzerland', "Germany" ]

# Novo DataFrame com 4 países
df4 = df4[df4["country"].isin(c)]

sns.pairplot(data = df4)

# %%
sns.pairplot(data = df4, hue ="country", diag_kind = "none")

# %%
sns.pairplot(data = df4, hue ="country", diag_kind = "none", palette = "viridis")

# %% [markdown]
# # Correlação

# %% [markdown]
# ## Correlação de Pearson, Sperman e Kendall
#
# O coeficiente de correlação de Pearson (r) é um número entre -1 e 1. Em geral, a correlação expressa o grau em que, em média, duas variáveis mudam de forma correspondente.
#
# O p-valor é a probabilidade de que você teria encontrado o resultado atual se o coeficiente de correlação fosse de fato zero (hipótese nula). Se esta probabilidade for menor que os 5% convencionais (P < 0,05), o coeficiente de correlação é chamado estatisticamente significativo.

# %%
pearson_coef, p_value = stats.pearsonr(df["hdi"], df["child_mortality"])
print("Pearson Correlation = ", pearson_coef)
print("p-value = ", p_value)

sperman_coef, p_value = stats.spearmanr(df["hdi"], df["child_mortality"])
print("Sperman Correlation = ", sperman_coef)
print("p-value = ", p_value)

tau, p_value = stats.kendalltau(df["hdi"], df["child_mortality"])
print("Kendall Correlation = ", tau)
print("p-value = ", p_value)
# Out:
# Pearson Correlation =  -0.8868012364245572
# p-value =  0.0
# Sperman Correlation =  -0.9517770880110796
# p-value =  0.0
# Kendall Correlation =  -0.8047090517282884
# p-value =  0.0

# %% [markdown]
# ## Matriz de correlações

# %%
# Cria a matrix de correlações
Var_Corr = df.corr(method = "spearman", numeric_only = True) #method = "kendall" method = "spearman"
# plot the heatmap and annotation on it
g = sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, 
                yticklabels=Var_Corr.columns, 
                annot=True,linewidths=.5, 
                cmap = "Spectral")
g.tick_params(labelsize=17)

# %% [markdown]
# # Regression plot

# %%
g = sns.regplot(y = "hdi", 
                x = "child_mortality", data = df2)

g.axes.set_title('Child Mortality vs HDI',fontsize=30)
g.set_xlabel("Child Mortality",fontsize=20)
g.set_ylabel("HDI",fontsize=20)
g.tick_params(labelsize=17)

# %%
df_corr = df2[["hdi","child_mortality"]].dropna()
pearson_coef, p_value = stats.pearsonr(df_corr["hdi"], df_corr["child_mortality"])
print("Pearson Correlation = ", pearson_coef)
print("p-value = ", p_value)
# Out:
# Pearson Correlation =  -0.8057331524269594
# p-value =  7.373857911334009e-26

# %%
df_bulgaria = df3[df3['country']=='Bulgaria']

sns.regplot(x = "hdi", y = "child_mortality", data = df_bulgaria)
# Out:
# <Axes: xlabel='hdi', ylabel='child_mortality'>

# %%
pearson_coef, p_value = stats.pearsonr(df_bulgaria["hdi"], df_bulgaria["child_mortality"])
print("Pearson Correlation = ", pearson_coef)
print("p-value = ", p_value)
# Out:
# Pearson Correlation =  -0.9937160747727538
# p-value =  2.659751650456933e-25

# %% [markdown]
# # Separando em países com HDI alto e baixo.

# %%
media_hdi = df["hdi"].mean()
mediana_hdi = df["hdi"].median()

print("Média do HDI: ", media_hdi)
print("Mediana do HDI: ", mediana_hdi)
# Out:
# Média do HDI:  0.6813606421256573
# Mediana do HDI:  0.705

# %%
sns.histplot(data=df, x="hdi")
# Out:
# <Axes: xlabel='hdi', ylabel='Count'>

# %% [markdown]
# ## Binning into High and Low HDI

# %%
#bins = np.linspace(min(df["hdi"]),max(df["hdi"]),3) # linearmente distribuidos
bins = [min(df["hdi"]),mediana_hdi ,max(df["hdi"]) ]  # corta na mediana
group_names = ["low","high"]
df["hdi_bin"] =  pd.cut(df["hdi"], bins, labels = group_names, include_lowest=True)
df.head()
# Out:
#        country  year  sanitation  child_mortality  total_fertility  \
# 0  Afghanistan  1999        23.5            129.0             7.49
# 1  Afghanistan  2000        23.5            125.0             7.39
# 2  Afghanistan  2001        24.6            121.0             7.27
# 3  Afghanistan  2002        25.8            117.0             7.14
# 4  Afghanistan  2003        26.9            113.0             6.99
#
#    co2_emissions  employment_rate    hdi   gdp  life_expectancy  population  \
# 0         0.0370             45.9  0.345   578             54.7    20800000
# 1         0.0376             45.9  0.347   563             54.8    21600000
# 2         0.0471             47.7  0.378  1190             55.5    22600000
# 3         0.0509             47.9  0.387  1240             56.5    23700000
# 4         0.0368             47.5  0.400  1200             57.1    24700000
#
#    suicide hdi_bin
# 0      NaN     low
# 1      NaN     low
# 2      NaN     low
# 3      NaN     low
# 4      NaN     low

# %%
df_hdi = df['hdi_bin'].value_counts().to_frame()
df_hdi.reset_index(inplace = True)
df_hdi.columns = ['hdi_bin', 'total']
df_hdi.head()
# Out:
#   hdi_bin  total
# 0     low   1808
# 1    high   1805

# %% [markdown]
# ## Separar o DF por HDI - Forma 1

# %%
df_high_hdi = df[df["hdi"] >= mediana_hdi]
df_high_hdi.head()
# Out:
#     country  year  sanitation  child_mortality  total_fertility  \
# 32  Albania  2005        92.9             17.9             1.70
# 33  Albania  2006        93.6             16.7             1.67
# 34  Albania  2007        94.3             15.5             1.65
# 35  Albania  2008        94.9             14.4             1.65
# 36  Albania  2009        95.6             13.3             1.65
#
#     co2_emissions  employment_rate    hdi    gdp  life_expectancy  population  \
# 32           1.27             47.7  0.709   8600             76.9     3060000
# 33           1.29             48.4  0.718   9180             77.5     3030000
# 34           1.46             47.9  0.724   9940             77.6     3000000
# 35           1.47             47.0  0.729  10300             78.0     2970000
# 36           1.56             46.6  0.740  10800             78.1     2950000
#
#     suicide hdi_bin
# 32      NaN    high
# 33     4.06    high
# 34     5.34    high
# 35      NaN    high
# 36     3.08    high

# %%
df_country_high_hdi = df_high_hdi['country'].value_counts().to_frame().reset_index()
c = df_country_high_hdi['country'].unique().tolist()
print("Países com Alto HDI em algum ano:\n",c)
# Out:
# Países com Alto HDI em algum ano:
#  ['France', 'Czech Republic', 'Spain', 'South Korea', 'Estonia', 'Slovenia', 'Finland', 'Germany', 'Greece', 'Hong Kong, China', 'Iceland', 'Singapore', 'Ireland', 'Israel', 'Italy', 'Japan', 'Luxembourg', 'Malta', 'Portugal', 'Netherlands', 'New Zealand', 'Denmark', 'Norway', 'Austria', 'Belgium', 'Australia', 'Sweden', 'United Kingdom', 'Canada', 'Switzerland', 'Hungary', 'Slovak Republic', 'Poland', 'United States', 'Lithuania', 'Kuwait', 'Barbados', 'Argentina', 'Chile', 'Croatia', 'Russia', 'Bulgaria', 'Latvia', 'Serbia', 'Romania', 'Costa Rica', 'Qatar', 'Mexico', 'Uruguay', 'Bahamas', 'Malaysia', 'Trinidad and Tobago', 'Cyprus', 'United Arab Emirates', 'Saudi Arabia', 'Panama', 'Bahrain', 'Oman', 'Jordan', 'Kazakhstan', 'Sri Lanka', 'Cuba', 'Mauritius', 'Ukraine', 'Belarus', 'Libya', 'Venezuela', 'Lebanon', 'Montenegro', 'Georgia', 'North Macedonia', 'Armenia', 'Azerbaijan', 'Bosnia and Herzegovina', 'Iran', 'St. Lucia', 'Albania', 'Algeria', 'Jamaica', 'Peru', 'Turkey', 'Ecuador', 'Brazil', 'Colombia', 'Thailand', 'St. Vincent and the Grenadines', 'Tunisia', 'Brunei', 'China', 'Suriname', 'Mongolia', 'Dominican Republic', 'Belize', 'Paraguay', 'Fiji', 'Botswana', 'Tonga', 'Moldova', 'Maldives', 'Turkmenistan', 'Philippines', 'Uzbekistan', 'Samoa']

# %% [markdown]
# ## Separar o DF por HDI - Forma 2

# %%
df_high_hdi = df[df["hdi_bin"] == "high"]
df_high_hdi.head()
# Out:
#     country  year  sanitation  child_mortality  total_fertility  \
# 32  Albania  2005        92.9             17.9             1.70
# 33  Albania  2006        93.6             16.7             1.67
# 34  Albania  2007        94.3             15.5             1.65
# 35  Albania  2008        94.9             14.4             1.65
# 36  Albania  2009        95.6             13.3             1.65
#
#     co2_emissions  employment_rate    hdi    gdp  life_expectancy  population  \
# 32           1.27             47.7  0.709   8600             76.9     3060000
# 33           1.29             48.4  0.718   9180             77.5     3030000
# 34           1.46             47.9  0.724   9940             77.6     3000000
# 35           1.47             47.0  0.729  10300             78.0     2970000
# 36           1.56             46.6  0.740  10800             78.1     2950000
#
#     suicide hdi_bin
# 32      NaN    high
# 33     4.06    high
# 34     5.34    high
# 35      NaN    high
# 36     3.08    high

# %%
# Cria a matrix de correlações
Var_Corr = df_high_hdi.corr(numeric_only = True)
# plot the heatmap and annotation on it
g = sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True,linewidths=.5, cmap = "Spectral")
g.tick_params(labelsize=17)
g.axes.set_title('HeatMap da Correlação de países com Alto HDI',fontsize=30)
# Out:
# Text(0.5, 1.0, 'HeatMap da Correlação de países com Alto HDI')

# %% [markdown]
# ### Países com baixo HDI

# %%
df_low_hdi = df[df["hdi_bin"] == "low"]
df_low_hdi.head()
# Cria a matrix de correlações
Var_Corr = df_low_hdi.corr(numeric_only = True)
# plot the heatmap and annotation on it
g=sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True,linewidths=.5, cmap = "Spectral")
g.tick_params(labelsize=17)
g.axes.set_title('HeatMap da Correlação de países com Baixo HDI',fontsize=30)
# Out:
# Text(0.5, 1.0, 'HeatMap da Correlação de países com Baixo HDI')

# %% [markdown]
# ## Suicídios e desemprego
# ### Países com baixo HDI

# %%
sns.regplot(x = "employment_rate", y = "suicide", data = df_low_hdi)
# Out:
# <Axes: xlabel='employment_rate', ylabel='suicide'>

# %% [markdown]
# ### Países com alto HDI

# %%
sns.regplot(x = "employment_rate", y = "suicide", data = df_high_hdi)
# Out:
# <Axes: xlabel='employment_rate', ylabel='suicide'>

# %% [markdown]
# # Existe diferença estatística na taxa o emprego (15 anos ou mais) em países com alto e baixo HDI ?
#
# ### Teste T

# %%
ttest ,pval = stats.ttest_ind(df_high_hdi["employment_rate"].dropna(), 
                              df_low_hdi["employment_rate"].dropna())
print("Estatística do teste: ",ttest)
print("P-Valor: ",pval)
# Out:
# Estatística do teste:  -7.643915057980763
# P-Valor:  2.683549713891535e-14

# %% [markdown]
# Um p-valor maior que um limiar escolhido (por exemplo, 5% ou 1%) indica que nossa observação não é tão improvável que tenha ocorrido por acaso. Portanto, não rejeitamos a hipótese nula de médias populacionais iguais. Se o p-valor for menor que nosso limiar, então temos evidências contra a hipótese nula de médias populacionais iguais.

# %% [markdown]
# ### Teste Z

# %%
from statsmodels.stats import weightstats as stests

ztest ,pval = stests.ztest(df_high_hdi["employment_rate"].dropna(), 
                           df_low_hdi["employment_rate"].dropna(), 
                           value=0, alternative='two-sided')
print("Estatística do teste: ",ztest)
print("P-Valor: ",pval)
# Out:
# Estatística do teste:  -7.643915057980762
# P-Valor:  2.1071444319902693e-14

# %% [markdown]
# ## Vamos explorar um pouquinho mais essa diferença

# %%
a = df_high_hdi["employment_rate"].dropna()
conf_interval = stats.t.interval(0.95, len(a)-1, loc=np.mean(a), scale=stats.sem(a))
print("Confidence Interval: ", conf_interval)

df_high_hdi["employment_rate"].describe()
# Out:
# Confidence Interval:  (np.float64(55.296646044853325), np.float64(56.101137888664674))
# count    1805.000000
# mean       55.698892
# std         8.713461
# min        28.900000
# 25%        50.400000
# 50%        56.500000
# 75%        60.900000
# max        87.400000
# Name: employment_rate, dtype: float64

# %%
a = df_low_hdi["employment_rate"].dropna()
conf_interval = stats.t.interval(0.95, len(a)-1, loc=np.mean(a), scale=stats.sem(a))
print("Confidence Interval: ", conf_interval)

df_low_hdi["employment_rate"].describe()
# Out:
# Confidence Interval:  (np.float64(57.891305192896034), np.float64(59.06997799294468))
# count    1808.000000
# mean       58.480642
# std        12.776838
# min        28.900000
# 25%        49.500000
# 50%        58.000000
# 75%        68.200000
# max        87.800000
# Name: employment_rate, dtype: float64

# %%
sns.boxplot(data=df, y="employment_rate", x = "hdi_bin")
# Out:
# <Axes: xlabel='hdi_bin', ylabel='employment_rate'>

# %%
g = sns.histplot(data=df, x="employment_rate", hue = "hdi_bin")
g.axes.set_title('Histogram of Employment Rate',fontsize=30)
g.set_xlabel("Employment Rate",fontsize=20)
g.set_ylabel("Count",fontsize=20)
g.tick_params(labelsize=17)

# %%
g = sns.histplot(data=df, x="employment_rate", hue = "hdi_bin", multiple="dodge")
g.axes.set_title('Histogram of Employment Rate',fontsize=30)
g.set_xlabel("Employment Rate",fontsize=20)
g.set_ylabel("Count",fontsize=20)
g.tick_params(labelsize=17)

# %% [markdown]
# # Entrega LAB
#
# Repita a análise comparando desemprego para países com alto e baixo HDI, mas agora para as variáveis emissão de Co2 e child mortality.
#
# Entrega mínima:
#
# * Testes de hipóteses
# * Gráficos, hitogramas
# * Correlação entre emissão de Co2 e child mortality
#
# Mas .... você tem alguma outra proposta de gráficos ou análises? Se sim entregue

# %% [markdown]
# ## Fique Conectado
#
# - [![YouTube](https://img.icons8.com/ios-filled/40/000000/youtube-play.png)](https://www.youtube.com/@LigaDataScience/videos)
#   Explore nossos vídeos educacionais e webinars sobre ciência de dados, machine learning e inteligência artificial. Inscreva-se para não perder nenhuma atualização!
#
# - [![LinkedIn](https://img.icons8.com/ios-filled/40/000000/linkedin.png)](https://www.linkedin.com/company/liga-data-science-ufpr/)
#   Siga-nos no LinkedIn para as últimas novidades, oportunidades de carreira e networking profissional no campo da ciência de dados.
#
# - [![Instagram](https://img.icons8.com/ios-filled/40/000000/instagram-new.png)](https://www.instagram.com/ligadatascience/)
#   Confira nosso Instagram para conteúdos dos bastidores, destaques de eventos e o dia a dia da Liga Data Science. Faça parte da nossa jornada!
#
# ## Autores
#
# <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pecora</a>,
#
# ## References
#
# * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html
# * https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.kendalltau.html
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
# * https://www.gapminder.org/data/
# * https://docs.profiling.ydata.ai/latest/
#
#
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-06  | 0.9  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Initial development |
# | 2021-03-12  | 1.0  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Basic Stats|
# | 2021-03-29  | 1.1  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Graphics and PandasProfile|
# | 2021-03-29  | 1.2  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Estrutura e atualizações|
#
# <hr>
